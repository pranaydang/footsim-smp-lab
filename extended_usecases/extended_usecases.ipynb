# %% [markdown]
# # Extended use cases of FootSim

# %%
from additional_usecases import *

# %%
# Paths #
figpath = ".\\"

# %% [markdown]
# # Afferent Firing Thresholds

# %%
individual_models_threshold_visualisation(absolute=10, figpath=figpath, matched=True);
# Out:
# Computing firing rates...
# C:\Users\me1rss\Documents\Git_repositories\footsim\python\validation\additional_usecases.py:1037: RuntimeWarning: invalid value encountered in greater
#   responsive_afferents[keys] = np.where(np.array(rates[keys], dtype=object) > absolute)
# Simulation started at:  Wed Oct 19 12:52:10 2022
# Simulation finished at:  Wed Oct 19 12:55:38 2022

# %% [markdown]
# # Receptive Fields' areas

# %%
RF_mod = model_RFs(); # Generate RF areas for the model
RFs_swarm(figpath=figpath, figname="ReceptiveFields.svg", RF_mod=RF_mod); # Visualise RF swarm plots

# %% [markdown]
# # Firing rates

# %%
FRs = individual_FRs(figpath=figpath, scatter=True); # Compute model FRs
# Out:
# Computing firing rates...

# %%
FR_scatters(figpath=figpath, comparison=FRs, figname="scatters"); # Plot Individual FR scatters

# %%
# Plots grouped scatters, frequency x amplitude pairs are colour-coded

FR_groupedscatters(figpath=figpath, comparison=FRs, figname="class_scatters")

# %%
#Rate intensity functions 
FR_intensity_functions(figpath=figpath, comparison=FRs, figname="rate_intensity")

# %% [markdown]
# # Ramp and hold stimuli

# %%
ramps,s = ramps_byclass('./', 'ramps.svg'); # Compute and plot response to ramp stimulus
