# %%
import footsim as fs
import numpy as np
import holoviews as hv # import holoviews package for plots and set some parameters
from footsim.plotting import plot
hv.notebook_extension()
# %output holomap='scrubber'

import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1b4b650c-95d7-4837-8b69-039a55a79106'>
#   <div id="b5ef1f18-e435-4afb-bb8d-1adb9cdb1ec5" data-root-id="1b4b650c-95d7-4837-8b69-039a55a79106" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
forefoot = []
hindfoot = []
a = fs.affpop_foot()

# Loop through the actual Afferent objects:
for aff in a.afferents:
    # aff.location is a (1,2) array [[x, y]], so:
    aff.location[0, 0] = 0   # set x → 20

# Now when you read the property, you’ll see that change:
for i in range(len(a.afferents)):
    if a.afferents[i].location[0,1] < 10 and a.afferents[i].location[0,1] > -30:
        forefoot.append(a.afferents[i])

    elif a.afferents[i].location[0,1] < -130 and a.afferents[i].location[0,1] > -170:
        hindfoot.append(a.afferents[i])

# %%
forefoot_population = fs.classes.AfferentPopulation()
hindfoot_population = fs.classes.AfferentPopulation()

# %%
hindfoot_population.afferents = hindfoot
forefoot_population.afferents = forefoot

# %%
# %%output size=250
# plot() * plot(hindfoot_population)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %%
# %%output size=250
# plot() * plot(forefoot_population)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %%
stim_forefoot = fs.stim_linear(len_prev=0, amp=10, freq=25, loc=(0,-10))
stim_hindfoot = fs.stim_linear(len_prev=0, amp=10, freq=25, loc=(0,-150))
# stim = fs.stim_sine(amp=10, freq=25)

# %%
plot(stim_forefoot)
# Out:
# :HoloMap   [Time bin [inf ms]]
#    :NdOverlay   [Element]
#       :Curve   [x]   (y)

# %%
r_forefoot = forefoot_population.response(stim_forefoot)
r_hindfoot = hindfoot_population.response(stim_hindfoot)
fr_forefoot = r_forefoot.rate()
fr_hindfoot = r_hindfoot.rate()

# %%
np.average(fr_hindfoot)
# Out:
# np.float64(2.1079136690647484)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
rows_with_pos = np.any(fr > 0, axis=1)
if rows_with_pos.any():
    i = np.flatnonzero(rows_with_pos)  # first such row index
    first_array = fr[i]
    print(i)
    # print(first_array)
else:
    print("No entries > 0 found.")
# Out:
# [   7   34   42   65   71   81   82  103  106  107  108  111  114  119
#   124  125  129  130  132  135  136  138  142  155  181  189  219 1037
#  1038 1044 1045 1048 1051 1052 1053 1066 1067 1068 1070 1071 1072 1073
#  1074 1076 1078 1079 1081 1082 1085 1086 1089 1090 1091 1092 1093 1094
#  1095 1096 1099 1100 1101 1103 1104 1105 1106 1108 1109 1113 1117 1118
#  1122 1124 1126 1127 1130 1134 1135 1136 1139 1140 1141 1144 1146 1149
#  1157 1158 1161 1162 1163 1164 1168 1169 1170 1171 1178 1186 1189 1197
#  1200 1201 1204 1268 1300 1327 1333 1340 1346]

# %%
angles = np.array([-5, 0, 5])

# Forefoot and hindfoot pressures
forefoot_pressures = np.array([8.1, 10.0, 12.2])
hindfoot_pressures = np.array([12.4, 10.9, 8.9])

# Generate scale factor to match with simulation
model_mass = 74
study_avg_mass = 64.5
scale_factor = model_mass / study_avg_mass

scaled_forefoot_pressures = forefoot_pressures * scale_factor
scaled_hindfoot_pressures = hindfoot_pressures * scale_factor

# Fit 2nd-degree polynomials
forefoot_poly = np.poly1d(np.polyfit(angles, scaled_forefoot_pressures, 2))
hindfoot_poly = np.poly1d(np.polyfit(angles, scaled_hindfoot_pressures, 2))

# %%
forefoot_poly(-5)
# Out:
# np.float64(9.293023255813946)

# %%
steps = 2000
angle = []

curr_angle = 0
angle.append(curr_angle)
for i in range(int(steps/4)):
    curr_angle += 10/steps
    angle.append(curr_angle)

for i in range(int(steps/2)):
    curr_angle -= 10/steps
    angle.append(curr_angle)

for i in range(int(steps/4)):
    curr_angle += 10/steps
    angle.append(curr_angle)

# %%
forefoot_pressure_array = forefoot_poly(angle)
hindfoot_pressure_array = hindfoot_poly(angle)

# %%
def pressure_to_delta_length(pressure_forefoot, pressure_hindfoot):

    # pressure is in N/cm^2
    pressure_forefoot /= 100
    pressure_hindfoot /= 100
    length_forefoot = 10 #in mm
    length_hindfoot = 30 #in mm
    youngs_forefoot = 0.29 # N/mm^2
    youngs_hindfoot = 0.39 # N/mm^2

    delta_length_forefoot = (pressure_forefoot*length_forefoot)/(youngs_forefoot)
    delta_length_hindfoot = (pressure_hindfoot*length_hindfoot)/(youngs_hindfoot)

    return delta_length_forefoot, delta_length_hindfoot

# %%
delta_length_forefoot, delta_length_hindfoot = pressure_to_delta_length(forefoot_pressure_array, hindfoot_pressure_array)

# %%
delta_length_forefoot
# Out:
# array([3.95616145, 3.95697253, 3.95778372, ..., 3.95453967, 3.9553505 ,
#        3.95616145], shape=(2001,))

# %%
forefoot_stimuli = []
hindfoot_stimuli = []
len_prev_fore = 10 + delta_length_forefoot[0]
len_prev_hind = 30 + delta_length_hindfoot[0]

for i in range(len(delta_length_forefoot)-1):

    forefoot_stimuli.append(fs.stim_linear(len_prev=len_prev_fore, amp=delta_length_forefoot[i+1]-delta_length_forefoot[i], freq=0.5, loc=(0,-10)))
    hindfoot_stimuli.append(fs.stim_linear(len_prev=len_prev_hind, amp=delta_length_hindfoot[i+1]-delta_length_hindfoot[i], freq=0.5, loc=(0,-150)))
    len_prev_fore +=  (delta_length_forefoot[i+1]-delta_length_forefoot[i])
    len_prev_hind +=  (delta_length_hindfoot[i+1]-delta_length_hindfoot[i])

# %%
afr_forefoot = []
afr_hindfoot = []

for i in range(700):
    response = forefoot_population.response(forefoot_stimuli[i])
    fr_forefoot = np.mean(response.rate())
    response = hindfoot_population.response(hindfoot_stimuli[i])
    fr_hindfoot = np.mean(response.rate())
    afr_forefoot.append(fr_forefoot)
    afr_hindfoot.append(fr_hindfoot)

afr_forefoot = np.array(afr_forefoot)
afr_hindfoot = np.array(afr_hindfoot)

# %%
plt.plot(afr_forefoot)

# %%
plt.plot(afr_hindfoot)

# %%
print(hindfoot_poly(0))
# Out:
# 12.505426356589144
