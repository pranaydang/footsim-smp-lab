# %%
import footsim as fs
import numpy as np
import holoviews as hv # import holoviews package for plots and set some parameters
from footsim.plotting import plot
hv.notebook_extension()
# %output holomap='scrubber'

import warnings
warnings.filterwarnings('ignore')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d9d5cd56-58ec-4598-8660-088055f08233'>
#   <div id="bce5c1b7-e4ab-44ab-8205-076ab0fb6beb" data-root-id="d9d5cd56-58ec-4598-8660-088055f08233" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b60dc978-546a-459e-b9d4-aa99ba46a397":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d9d5cd56-58ec-4598-8660-088055f08233"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"36683381-5910-4d76-b430-757192f5908a","attributes":{"plot_id":"d9d5cd56-58ec-4598-8660-088055f08233","comm_id":"979cfb22e1564fc79f3402a98d82725e","client_comm_id":"134d77d03f1342bb88d071c2371eacdc"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"b60dc978-546a-459e-b9d4-aa99ba46a397","roots":{"d9d5cd56-58ec-4598-8660-088055f08233":"bce5c1b7-e4ab-44ab-8205-076ab0fb6beb"},"root_ids":["d9d5cd56-58ec-4598-8660-088055f08233"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # Foot outline

# %% [markdown]
# `footsim` includes a model of the foot surface. Its coordinate system is centered on the MMi region. Other spatial layouts can be used via the `Surface` class.

# %%
# %%output size=250
# plot(coord=10,tags=True)
# Out:
# :Overlay
#    .Path.I   :Path   [x,y]
#    .Curve.I  :Curve   [x]   (y)
#    .Curve.II :Curve   [x]   (y)
#    .Labels.I :Labels   [x,y]   (Label)

# %% [markdown]
# # Creating an afferent population

# %% [markdown]
# `footsim` includes several `affpop_*` functions that generate commonly used `AfferentPopulation` objects. To create an afferent population on the foot with realistic afferent densities in each region, use the `affpop_foot()` function.

# %%
a = fs.affpop_foot()
print(a)
# Out:
# AfferentPopulation with 1514 afferent(s): 249 SA1, 314 SA2, 777 FA1, 174 FA2.

# %% [markdown]
# To visualise the afferent innervation of the foot, pass the afferent population object `a` to the `plot` function.

# %%
# %%output size=250
# plot() * plot(a)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %% [markdown]
# To only view a single afferent class, index the afferent population using the name of that class.

# %%
# %%output size=250
# plot() * plot(a['FA1'])
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %% [markdown]
# There are multiple arguments for `affpop_foot()`, which affect the afferent population that is gnerated.
#  - region (str): limits the population to the region specifed
#  - affclass (str): limits the population to the afferent class specified
#  - density_multiplier (float): reduces (if <1) or increases (if >1) the afferent densities relative to their baseline

# %%
# %%output size=250
# a_low_density = fs.affpop_foot(affclass='SA1', density_multiplier = 0.5)
# plot() * plot(a_low_density)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %% [markdown]
# # Generating stimuli

# %% [markdown]
# Commonly used types of stimuli are included via `stim_*` functions. These include:
#  - Ramp-and-hold stimuli
#  - Sinusoidal vibrations
#  - Generation of different shapes (e.g. circular or bar)

# %% [markdown]
# ## Ramp-and-hold stimuli

# %% [markdown]
# This example generates a circular probe with a radius of 3mm that is indented and then retracted in a ramp-and-hold pattern.

# %%
s_ramp = fs.stim_ramp(pin_radius=3., ramp_type='sin', ramp_len=0.2)

# %% [markdown]
# Calling the `plot` function shows the temporal profile of the indentation trace:

# %%
plot(s_ramp)
# Out:
# :HoloMap   [Time bin [inf ms]]
#    :NdOverlay   [Element]
#       :Curve   [x]   (y)

# %% [markdown]
# The stimulus can also be plotted spatially, showing the pin outline(s) on the surface of the foot sole.

# %%
plot() * plot(s_ramp, spatial=True,bin=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plot() * plot(s_ramp, spatial=True,bin=10)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\IPython\core\formatters.py:208, in DisplayFormatter.format(self, obj, include, exclude)
#     204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
# --> 208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     210 if format_dict or md_dict:
#     211     if include:
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\IPython\core\formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\core\dimension.py:1275, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1268 def _repr_mimebundle_(self, include=None, exclude=None):
#    1269     """
#    1270     Resolves the class hierarchy for the class rendering the
#    1271     object using any display hooks registered on Store.display
#    1272     hooks.  The output of all registered display_hooks is then
#    1273     combined and returned.
#    1274     """
# -> 1275     return Store.render(self)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\core\options.py:1423, in Store.render(cls, obj)
#    1421 data, metadata = {}, {}
#    1422 for hook in hooks:
# -> 1423     ret = hook(obj)
#    1424     if ret is None:
#    1425         continue
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\ipython\display_hooks.py:287, in pprint_display(obj)
#     285 if not ip.display_formatter.formatters['text/plain'].pprint:
#     286     return None
# --> 287 return display(obj, raw_output=True)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\ipython\display_hooks.py:261, in display(obj, raw_output, **kwargs)
#     259 elif isinstance(obj, (HoloMap, DynamicMap)):
#     260     with option_state(obj):
# --> 261         output = map_display(obj)
#     262 elif isinstance(obj, Plot):
#     263     output = render(obj)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\ipython\display_hooks.py:149, in display_hook.<locals>.wrapped(element)
#     147 try:
#     148     max_frames = OutputSettings.options['max_frames']
# --> 149     mimebundle = fn(element, max_frames=max_frames)
#     150     if mimebundle is None:
#     151         return {}, {}
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\ipython\display_hooks.py:209, in map_display(vmap, max_frames)
#     206     max_frame_warning(max_frames)
#     207     return None
# --> 209 return render(vmap)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\ipython\display_hooks.py:76, in render(obj, **kwargs)
#      73 if renderer.fig == 'pdf':
#      74     renderer = renderer.instance(fig='png')
# ---> 76 return renderer.components(obj, **kwargs)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\renderer.py:396, in Renderer.components(self, obj, fmt, comm, **kwargs)
#     394 embed = (not (dynamic or streams or self.widget_mode == 'live') or config.embed)
#     395 if embed or config.comms == 'default':
# --> 396     return self._render_panel(plot, embed, comm)
#     397 return self._render_ipywidget(plot)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\renderer.py:403, in Renderer._render_panel(self, plot, embed, comm)
#     401 doc = Document()
#     402 with config.set(embed=embed):
# --> 403     model = plot.layout._render_model(doc, comm)
#     404 if embed:
#     405     return render_model(model, comm)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\panel\viewable.py:762, in Viewable._render_model(self, doc, comm)
#     759     doc.theme = self._design.theme.bokeh_theme
#     761 if config.embed:
# --> 762     embed_state(self, model, doc,
#     763                 json=config.embed_json,
#     764                 json_prefix=config.embed_json_prefix,
#     765                 save_path=config.embed_save_path,
#     766                 load_path=config.embed_load_path,
#     767                 progress=False)
#     768 else:
#     769     add_to_doc(model, doc)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\panel\io\embed.py:340, in embed_state(panel, model, doc, max_states, max_opts, json, json_prefix, save_path, load_path, progress, states)
#     338     with always_changed(config.safe_embed):
#     339         for w in ws:
# --> 340             w.value = k
#     341 except Exception:
#     342     skip = True
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:515, in instance_descriptor.<locals>._f(self, obj, val)
#     513         instance_param = _instantiated_parameter(obj, self)
#     514     if instance_param is not None and self is not instance_param:
# --> 515         instance_param.__set__(obj, val)
#     516         return
#     517 return f(self, obj, val)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:517, in instance_descriptor.<locals>._f(self, obj, val)
#     515         instance_param.__set__(obj, val)
#     516         return
# --> 517 return f(self, obj, val)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameters.py:541, in Dynamic.__set__(self, obj, val)
#     532 @instance_descriptor
#     533 def __set__(self,obj,val):
#     534     """
#     535     Call the superclass's set and keep this parameter's
#     536     instantiate value up to date (dynamic parameters
#    (...)
#     539     If val is dynamic, initialize it as a generator.
#     540     """
# --> 541     super().__set__(obj,val)
#     543     dynamic = callable(val)
#     544     if dynamic: self._initialize_generator(val,obj)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:517, in instance_descriptor.<locals>._f(self, obj, val)
#     515         instance_param.__set__(obj, val)
#     516         return
# --> 517 return f(self, obj, val)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:1564, in Parameter.__set__(self, obj, val)
#    1562 # Copy watchers here since they may be modified inplace during iteration
#    1563 for watcher in sorted(watchers, key=lambda w: w.precedence):
# -> 1564     obj.param._call_watcher(watcher, event)
#    1565 if not obj.param._BATCH_WATCH:
#    1566     obj.param._batch_call_watchers()
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:2604, in Parameters._call_watcher(self_, watcher, event)
#    2602 event = self_._update_event_type(watcher, event, self_._TRIGGER)
#    2603 with _batch_call_watchers(self_.self_or_cls, enable=watcher.queued, run=False):
# -> 2604     self_._execute_watcher(watcher, (event,))
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:2586, in Parameters._execute_watcher(self, watcher, events)
#    2584 else:
#    2585     try:
# -> 2586         watcher.fn(*args, **kwargs)
#    2587     except Skip:
#    2588         pass
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\panel\pane\holoviews.py:349, in HoloViews._widget_callback(self, event)
#     347 def _widget_callback(self, event):
#     348     for _, (plot, pane) in self._plots.items():
# --> 349         self._update_plot(plot, pane)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\panel\pane\holoviews.py:340, in HoloViews._update_plot(self, plot, pane)
#     338             plot.update(key)
#     339 else:
# --> 340     plot.update(key)
#     341     if hasattr(plot.renderer, 'get_plot_state'):
#     342         pane.object = plot.renderer.get_plot_state(plot)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\mpl\plot.py:289, in MPLPlot.update(self, key)
#     287 if len(self) == 1 and key in (0, self.keys[0]) and not self.drawn:
#     288     return self.initialize_plot()
# --> 289 return self.__getitem__(key)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\plot.py:444, in DimensionedPlot.__getitem__(self, frame)
#     442 if not isinstance(frame, tuple):
#     443     frame = self.keys[frame]
# --> 444 self.update_frame(frame)
#     445 return self.state
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\mpl\plot.py:62, in mpl_rc_context.<locals>.wrapper(self, *args, **kwargs)
#      60 def wrapper(self, *args, **kwargs):
#      61     with _rc_context(self.fig_rcparams):
# ---> 62         return f(self, *args, **kwargs)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\mpl\element.py:1239, in OverlayPlot.update_frame(self, key, ranges, element)
#    1237             if not exact:
#    1238                 self._update_subplot(subplot, spec)
# -> 1239     subplot.update_frame(key, ranges, el)
#    1241 if isinstance(self.hmap, DynamicMap) and items:
#    1242     self._create_dynamic_subplots(key, items, ranges)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\mpl\plot.py:62, in mpl_rc_context.<locals>.wrapper(self, *args, **kwargs)
#      60 def wrapper(self, *args, **kwargs):
#      61     with _rc_context(self.fig_rcparams):
# ---> 62         return f(self, *args, **kwargs)
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\mpl\element.py:532, in ElementPlot.update_frame(self, key, ranges, element)
#     529 if element is None:
#     530     return
# --> 532 ranges = self.compute_ranges(self.hmap, key, ranges)
#     533 ranges = util.match_spec(element, ranges)
#     535 max_cycles = self.style._max_cycles
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\plot.py:615, in DimensionedPlot.compute_ranges(self, obj, key, ranges)
#     611     # Only compute ranges if not axiswise on a composite plot
#     612     # or not framewise on a Overlay or ElementPlot
#     613     if (not (axiswise and not isinstance(obj, HoloMap)) or
#     614         (not framewise and isinstance(obj, HoloMap))):
# --> 615         self._compute_group_range(group, elements, ranges, framewise,
#     616                                   axiswise, robust, self.top_level,
#     617                                   prev_frame)
#     618 self.ranges.update(ranges)
#     619 return ranges
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\plotting\plot.py:725, in DimensionedPlot._compute_group_range(cls, group, elements, ranges, framewise, axiswise, robust, top_level, prev_frame)
#     723     data_range = ds.range(el_dim, dimension_range=False)
#     724 else:
# --> 725     data_range = el.range(el_dim, dimension_range=False)
#     727 data_ranges[(el, el_dim)] = data_range
#     728 if dtype is not None and dtype.kind in 'uif' and robust:
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\holoviews\core\data\__init__.py:200, in PipelineMeta.pipelined.<locals>.pipelined_fn(*args, **kwargs)
#     197 if PipelineMeta.disable:
#     198     return result
# --> 200 op = method_op.instance(
#     201     input_type=type(inst),
#     202     method_name=method_name,
#     203     args=list(args[1:]),
#     204     kwargs=kwargs,
#     205 )
#     207 if not in_method:
#     208     if isinstance(result, Dataset):
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:4617, in ParameterizedFunction.instance(self_or_cls, **params)
#    4614     cls = self_or_cls.__class__
#    4616 inst=Parameterized.__new__(cls)
# -> 4617 Parameterized.__init__(inst,**params)
#    4618 if 'name' in params:  inst.__name__ = params['name']
#    4619 else:                 inst.__name__ = self_or_cls.name
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:4325, in Parameterized.__init__(self, **params)
#    4323 if self.param.name.default == self.__class__.__name__:
#    4324     self.param._generate_name()
# -> 4325 refs, deps = self.param._setup_params(**params)
#    4326 object_count += 1
#    4328 self._param__private.initialized = True
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:1697, in as_uninitialized.<locals>.override_initialization(self_, *args, **kw)
#    1695 original_initialized = parameterized_instance._param__private.initialized
#    1696 parameterized_instance._param__private.initialized = False
# -> 1697 ret = fn(self_, *args, **kw)
#    1698 parameterized_instance._param__private.initialized = original_initialized
#    1699 return ret
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:1961, in Parameters._setup_params(self_, **params)
#    1959 if name not in self_.cls._param__private.explicit_no_refs:
#    1960     try:
# -> 1961         ref, _, resolved, _ = self_._resolve_ref(pobj, val)
#    1962     except Exception:
#    1963         ref = None
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:2048, in Parameters._resolve_ref(self_, pobj, value)
#    2046 is_gen = inspect.isgeneratorfunction(value)
#    2047 is_async = iscoroutinefunction(value) or is_gen
# -> 2048 deps = resolve_ref(value, recursive=pobj.nested_refs)
#    2049 if not (deps or is_async or is_gen):
#    2050     return None, None, value, False
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:198, in resolve_ref(reference, recursive)
#     196     elif isinstance(reference, slice):
#     197         return [r for v in (reference.start, reference.stop, reference.step) for r in resolve_ref(v, recursive)]
# --> 198 reference = transform_reference(reference)
#     199 if hasattr(reference, '_dinfo'):
#     200     dinfo = getattr(reference, '_dinfo', {})
#
# File c:\Users\prana\anaconda3\envs\fs\Lib\site-packages\param\parameterized.py:143, in transform_reference(arg)
#     135 """
#     136 Applies transforms to turn objects which should be treated like
#     137 a parameter reference into a valid reference that can be resolved
#    (...)
#     140 definitions.
#     141 """
#     142 for transform in _reference_transforms:
# --> 143     if isinstance(arg, Parameter) or hasattr(arg, '_dinfo'):
#     144         break
#     145     arg = transform(arg)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sinusoidal vibration

# %% [markdown]
# Sinusoidal vibrations can be generated using the `stim_sine` function.

# %%
s_sine = fs.stim_sine(freq=25)
plot(s_sine)
# Out:
# :HoloMap   [Time bin [inf ms]]
#    :NdOverlay   [Element]
#       :Curve   [x]   (y)

# %% [markdown]
# ## Complex shapes

# %% [markdown]
# Complex shapes can be created by simulating multiple probes simultaneously. A variety of different shapes can be created using the `shape_*` functions. Using the `stim_indent_shape` function, these shapes can then be combined with indentation profiles, e.g. generated by any of the `stim_*` functions to generate complex stimuli. The example below generates an elongated bar that is indented into the metatarsal region in a ramp-and-hold profile

# %%
s_bar = fs.stim_indent_shape(fs.shape_bar(width=50,height=20,pins_per_mm=0.5),
                             fs.stim_ramp(amp=0.9,len=0.5,ramp_type='sin',ramp_len=0.25, pin_radius=3))
plot() * plot(s_bar,spatial=True, bin=10)

# %% [markdown]
# The example below generates a circular domed stimulus that is indented into the heel region.

# %%
loc = (fs.foot_surface.centers[fs.foot_surface.tag2idx('HL')] + fs.foot_surface.centers[fs.foot_surface.tag2idx('HR')])/2.
s_bar = fs.stim_indent_shape(fs.shape_circle(center=loc,hdiff=0.5, radius=15,pins_per_mm=0.5),
                             fs.stim_ramp(amp=0.9,len=0.5,ramp_type='sin',ramp_len=0.25, pin_radius=3))
plot() * plot(s_bar,spatial=True, bin=10)

# %% [markdown]
# # Calculating responses

# %% [markdown]
# The `response` method of `Afferent` and `AfferentPopulation` objects calculates the spiking response to any `Stimulus` object.

# %%
r = a.response(s_sine)

# %% [markdown]
# Calling the `plot` function produces a raster plot showing the spikes generated by each afferent in the population over time.

# %%
plot(r)
# Out:
# matplotlib backend could not plot any Elements in the Overlay.
# :NdOverlay   [Element]

# %% [markdown]
# Neural responses can also be visualised spatially on the foot sole.

# %%
# %%output size=250
# plot() * plot(r,spatial=True,bin=50)

# %% [markdown]
# # Foot surface attributes

# %% [markdown]
# To find the centre coordinates for a region, use the `centers` property

# %%
centers = fs.foot_surface.centers
centers

# %% [markdown]
# To find which region a pair of coordinates is in, call the `locate` function

# %%
fs.foot_surface.locate(centers[0])

# %% [markdown]
# To find the area of each of the foot regions in mm<sup>2</sup>, use the `area` property

# %%
fs.foot_surface.area

# %% [markdown]
# You can find the coordinates for the foot boundaries using the `boundaries` property

# %%
fs.foot_surface.boundaries

# %% [markdown]
# To find the density of each afferent in each region of the foot, call the `density` property

# %%
fs.foot_surface.density
